# %%
# !pip install -q --upgrade torch==2.5.1+cu124 torchvision==0.20.1+cu124 torchaudio==2.5.1+cu124 --index-url https://download.pytorch.org/whl/cu124
# !pip install -q --upgrade requests==2.32.3 bitsandbytes==0.46.0 transformers==4.48.3 accelerate==1.3.0 datasets==3.2.0 peft==0.14.0 trl==0.14.0 matplotlib wandb
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.2/908.2 MB 1.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 45.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 83.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 93.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 115.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 16.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 9.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 95.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.6/209.6 MB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 113.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 13.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 98.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.6/336.6 kB 27.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 36.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.8/374.8 kB 31.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.9/313.9 kB 26.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 79.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 17.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 78.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.3 which is incompatible.
# google-adk 1.13.0 requires requests<3.0.0,>=2.32.4, but you have requests 2.32.3 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.9.0 which is incompatible.

# %%
import os
import re
import math
from tqdm import tqdm
from google.colab import userdata
from huggingface_hub import login
import torch
import torch.nn.functional as F
import transformers
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, set_seed
from datasets import load_dataset, Dataset, DatasetDict
from datetime import datetime
from peft import PeftModel
import matplotlib.pyplot as plt

# %%
BASE_MODEL = "meta-llama/Meta-Llama-3.1-8B"
PROJECT_NAME = "pricerbybhavin"
HF_USER = "bhavin200420"



PROJECT_RUN_NAME = "bhavin200420/pricerbybhavin-2025-09-11_11.52.43"
REVISION = None
FINETUNED_MODEL = "bhavin200420/pricerbybhavin-2025-09-11_11.52.43"



DATASET_NAME = "bhavin200420/amazon-appliances-dataset2025-09-10"

# %matplotlib inline

# %%
hf_token = userdata.get('HF_TOKEN')
login(hf_token, add_to_git_credential=True)

# %%
dataset = load_dataset(DATASET_NAME)
test = dataset['test']
# Out:
# README.md:   0%|          | 0.00/528 [00:00<?, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/8.53M [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet:   0%|          | 0.00/2.23M [00:00<?, ?B/s]
# data/validation-00000-of-00001.parquet:   0%|          | 0.00/478k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/21700 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/5725 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/1200 [00:00<?, ? examples/s]

# %%
test[0]
# Out:
# {'text': 'How much does this cost to the nearest dollar?\n\nDiscount Parts Direct Oven Bake Element Heating Element for Frigidaire Kenmore, Replaces\nReplaces the following part numbers Works for brands Electrolux, Frigidaire, Gibson, Kelvinator, Westinghouse, and others This part fixes the following symptoms Little to no heat when baking Element will not heat Oven not heating evenly Will Not Start Contact Us If you are not sure if part is correct, ask us in Customer questions & answers section or contact us by visiting the Discount Parts Direct storefront. Business Wholesale We are a small local company from Houston, Texas offer discount parts for retail and wholesale. If you need to purchase parts for business, please contact us for lower rates. Part Number Replaces Works for brand This oven heating element replacement Works for Electrolux, Frigidaire\n\nPrice is $',
#  'price': 26.97}

# %%
quant_config = BitsAndBytesConfig(
  load_in_4bit=True,
  bnb_4bit_use_double_quant=True,
  bnb_4bit_compute_dtype=torch.bfloat16,
  bnb_4bit_quant_type="nf4"
)

# %%
tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

base_model = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL,
    quantization_config=quant_config,
    device_map="auto",
)
base_model.generation_config.pad_token_id = tokenizer.pad_token_id

fine_tuned_model = PeftModel.from_pretrained(base_model, FINETUNED_MODEL)


print(f"Memory footprint: {fine_tuned_model.get_memory_footprint() / 1e6:.1f} MB")
# Out:
# tokenizer_config.json:   0%|          | 0.00/50.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/826 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/185 [00:00<?, ?B/s]
# adapter_config.json:   0%|          | 0.00/753 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/109M [00:00<?, ?B/s]
# Memory footprint: 5700.6 MB

# %%
fine_tuned_model
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): LlamaForCausalLM(
#       (model): LlamaModel(
#         (embed_tokens): Embedding(128256, 4096)
#         (layers): ModuleList(
#           (0-31): 32 x LlamaDecoderLayer(
#             (self_attn): LlamaAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.15, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (k_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.15, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.15, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (o_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.15, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#             )
#             (mlp): LlamaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (act_fn): SiLU()
#             )
#             (input_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#             (post_attention_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#           )
#         )
#         (norm): LlamaRMSNorm((4096,), eps=1e-05)
#         (rotary_emb): LlamaRotaryEmbedding()
#       )
#       (lm_head): Linear(in_features=4096, out_features=128256, bias=False)
#     )
#   )
# )

# %%
def extract_price(s):
    if "Price is $" in s:
      contents = s.split("Price is $")[1]
      contents = contents.replace(',','')
      match = re.search(r"[-+]?\d*\.\d+|\d+", contents)
      return float(match.group()) if match else 0
    return 0

# %%
extract_price("Price is $a fabulous 899.99 or so")
# Out:
# 899.99

# %%
def model_predict(prompt):
    set_seed(42)
    inputs = tokenizer.encode(prompt, return_tensors="pt").to("cuda")
    attention_mask = torch.ones(inputs.shape, device="cuda")
    outputs = fine_tuned_model.generate(inputs, attention_mask=attention_mask, max_new_tokens=3, num_return_sequences=1)
    response = tokenizer.decode(outputs[0])
    print(response)
    return extract_price(response)

# %%
top_K = 5

def improved_model_predict(prompt, device="cuda"):
    set_seed(42)
    inputs = tokenizer.encode(prompt, return_tensors="pt").to(device)
    attention_mask = torch.ones(inputs.shape, device=device)

    with torch.no_grad():
        outputs = fine_tuned_model(inputs, attention_mask=attention_mask)
        next_token_logits = outputs.logits[:, -1, :].to('cpu')

    next_token_probs = F.softmax(next_token_logits, dim=-1)
    top_prob, top_token_id = next_token_probs.topk(top_K)
    prices, weights = [], []
    for i in range(top_K):
      predicted_token = tokenizer.decode(top_token_id[0][i])
      probability = top_prob[0][i]
      try:
        result = float(predicted_token)
      except ValueError as e:
        result = 0.0
      if result > 0:
        prices.append(result)
        weights.append(probability)
    if not prices:
      return 0.0, 0.0
    total = sum(weights)
    weighted_prices = [price * weight / total for price, weight in zip(prices, weights)]
    return sum(weighted_prices).item()

# %%
class Tester:

    def __init__(self, predictor, data, title=None, size=250):
        self.predictor = predictor
        self.data = data
        self.title = title or predictor.__name__.replace("_", " ").title()
        self.size = size
        self.guesses = []
        self.truths = []
        self.errors = []
        self.sles = []
        self.colors = []

    def color_for(self, error, truth):
        if error<40 or error/truth < 0.2:
            return "green"
        elif error<80 or error/truth < 0.4:
            return "orange"
        else:
            return "red"

    def run_datapoint(self, i):
        datapoint = self.data[i]
        guess = self.predictor(datapoint["text"])
        truth = datapoint["price"]
        error = abs(guess - truth)
        log_error = math.log(truth+1) - math.log(guess+1)
        sle = log_error ** 2
        color = self.color_for(error, truth)
        title = datapoint["text"].split("\n\n")[1][:20] + "..."
        self.guesses.append(guess)
        self.truths.append(truth)
        self.errors.append(error)
        self.sles.append(sle)
        self.colors.append(color)
        print(f"{COLOR_MAP[color]}{i+1}: Guess: ${guess:,.2f} Truth: ${truth:,.2f} Error: ${error:,.2f} SLE: {sle:,.2f} Item: {title}{RESET}")

    def chart(self, title):
        max_error = max(self.errors)
        plt.figure(figsize=(12, 8))
        max_val = max(max(self.truths), max(self.guesses))
        plt.plot([0, max_val], [0, max_val], color='deepskyblue', lw=2, alpha=0.6)
        plt.scatter(self.truths, self.guesses, s=3, c=self.colors)
        plt.xlabel('Ground Truth')
        plt.ylabel('Model Estimate')
        plt.xlim(0, max_val)
        plt.ylim(0, max_val)
        plt.title(title)
        plt.show()

    def report(self):
        average_error = sum(self.errors) / self.size
        rmsle = math.sqrt(sum(self.sles) / self.size)
        hits = sum(1 for color in self.colors if color=="green")
        title = f"{self.title} Error=${average_error:,.2f} RMSLE={rmsle:,.2f} Hits={hits/self.size*100:.1f}%"
        self.chart(title)

    def run(self):
        self.error = 0
        for i in range(self.size):
            self.run_datapoint(i)
        self.report()

    @classmethod
    def test(cls, function, data):
        cls(function, data).run()

# %%
Tester.test(improved_model_predict, test)
# Out:
# 1: Guess: $24.44 Truth: $26.97 Error: $2.53 SLE: 0.01 Item: Discount Parts Direc...
# 2: Guess: $30.50 Truth: $36.99 Error: $6.49 SLE: 0.04 Item: BestRec Dryer Vent H...
# 3: Guess: $35.88 Truth: $41.33 Error: $5.45 SLE: 0.02 Item: Fuxury 12 Inch Impul...
# 4: Guess: $29.08 Truth: $45.02 Error: $15.94 SLE: 0.18 Item: Compatible Dryer Hea...
# 5: Guess: $10.94 Truth: $13.97 Error: $3.03 SLE: 0.05 Item: 694089 Dryer Blower ...
# 6: Guess: $59.44 Truth: $55.65 Error: $3.79 SLE: 0.00 Item: Compatible with Whir...
# 7: Guess: $17.59 Truth: $20.99 Error: $3.40 SLE: 0.03 Item: Replacement Aluminum...
# 8: Guess: $29.36 Truth: $30.68 Error: $1.32 SLE: 0.00 Item: Lifetime Appliance P...
# 9: Guess: $80.31 Truth: $57.99 Error: $22.32 SLE: 0.10 Item: OEM LG Refrigerator ...
# 10: Guess: $9.30 Truth: $8.99 Error: $0.31 SLE: 0.00 Item: Dryer Lint Filter Re...
# 11: Guess: $17.58 Truth: $25.95 Error: $8.37 SLE: 0.14 Item: FAMCO Dryer Vent Cov...
# 12: Guess: $17.62 Truth: $13.99 Error: $3.63 SLE: 0.05 Item: HIFROM Humidifier Wi...
# 13: Guess: $24.28 Truth: $13.27 Error: $11.01 SLE: 0.33 Item: - LG Refrigerator Re...
# 14: Guess: $23.58 Truth: $33.69 Error: $10.11 SLE: 0.12 Item: Frigidaire Surface B...
# 15: Guess: $9.95 Truth: $9.95 Error: $0.00 SLE: 0.00 Item: High Limit Thermosta...
# 16: Guess: $37.31 Truth: $106.48 Error: $69.17 SLE: 1.06 Item: Frigidaire Surface B...
# 17: Guess: $14.95 Truth: $21.36 Error: $6.41 SLE: 0.11 Item: EnviroCare Replaceme...
# 18: Guess: $122.50 Truth: $119.99 Error: $2.51 SLE: 0.00 Item: MAT Expert Counterto...
# 19: Guess: $17.84 Truth: $8.95 Error: $8.89 SLE: 0.41 Item: Magic Chef Magic Ste...
# 164: Guess: $121.81 Truth: $87.99 Error: $33.82 SLE: 0.10 Item: Clothes Dryer 110V E...
# 165: Guess: $10.94 Truth: $3.99 Error: $6.95 SLE: 0.76 Item: New Plastic Spray Bo...
# 166: Guess: $230.12 Truth: $168.17 Error: $61.96 SLE: 0.10 Item: 2.7 cubic foot compa...
# 167: Guess: $21.94 Truth: $35.21 Error: $13.27 SLE: 0.21 Item: SharkBite 26038 1/2 ...
# 168: Guess: $12.09 Truth: $15.99 Error: $3.90 SLE: 0.07 Item: LZJIQNZE Egg Holder ...
# 169: Guess: $36.06 Truth: $35.99 Error: $0.07 SLE: 0.00 Item: 4-Pack Replacement f...
# 170: Guess: $12.73 Truth: $42.99 Error: $30.26 SLE: 1.36 Item: Integra Boost RH 62%...
# 171: Guess: $91.88 Truth: $98.86 Error: $6.98 SLE: 0.01 Item: LG Electronics Refri...
# 172: Guess: $7.02 Truth: $7.99 Error: $0.97 SLE: 0.01 Item: Dryer Idler Pulley R...
# 173: Guess: $9.86 Truth: $5.99 Error: $3.87 SLE: 0.19 Item: 2 Packs French Press...
# 174: Guess: $33.56 Truth: $23.89 Error: $9.67 SLE: 0.11 Item: Artilife Multi-Funct...
# 175: Guess: $40.03 Truth: $97.38 Error: $57.35 SLE: 0.76 Item: Whirlpool Motor, Whi...
# 176: Guess: $26.27 Truth: $17.79 Error: $8.48 SLE: 0.14 Item: iSpring ICEK3 3/8 Tu...
# 177: Guess: $35.84 Truth: $33.99 Error: $1.85 SLE: 0.00 Item: EXCELPURE Replacemen...
# 178: Guess: $159.00 Truth: $177.95 Error: $18.95 SLE: 0.01 Item: LG Refrigerator Elec...
# 179: Guess: $29.75 Truth: $59.06 Error: $29.31 SLE: 0.45 Item: Whirlpool OEM Range ...
# 180: Guess: $13.97 Truth: $16.99 Error: $3.02 SLE: 0.03 Item: Beaquicy TDIDVKZW In...
# 181: Guess: $24.78 Truth: $57.44 Error: $32.66 SLE: 0.67 Item: Frigidaire 3 Door Ha...
# 182: Guess: $17.52 Truth: $14.99 Error: $2.53 SLE: 0.02 Item: MG Coffee 3 PACK Reu...
# 183: Guess: $17.81 Truth: $11.75 Error: $6.06 SLE: 0.15 Item: GE Dishwasher Door L...
# 184: Guess: $14.02 Truth: $13.99 Error: $0.03 SLE: 0.00 Item: Mist Water Filter Re...
# 185: Guess: $37.84 Truth: $37.45 Error: $0.39 SLE: 0.00 Item: PASSE Black Tile Flo...
# 186: Guess: $27.31 Truth: $49.99 Error: $22.68 SLE: 0.35 Item: Repairwares Refriger...
# 187: Guess: $38.03 Truth: $71.87 Error: $33.84 SLE: 0.39 Item: GE Refrigerator Door...
# 188: Guess: $12.09 Truth: $7.99 Error: $4.10 SLE: 0.14 Item: Stainless Steel Bell...
# 189: Guess: $11.94 Truth: $28.34 Error: $16.40 SLE: 0.67 Item: Filter Everything Re...
# 190: Guess: $234.62 Truth: $289.99 Error: $55.37 SLE: 0.04 Item: Bonnlo 13 lbs Portab...
# 191: Guess: $9.20 Truth: $5.89 Error: $3.31 SLE: 0.15 Item: PANSHA Door Knob Cov...
# 192: Guess: $21.47 Truth: $7.26 Error: $14.21 SLE: 1.00 Item: TraveT Digital Camer...
# 193: Guess: $10.92 Truth: $14.99 Error: $4.07 SLE: 0.09 Item: ZAWAGIIK Refrigerato...
# 194: Guess: $23.95 Truth: $21.99 Error: $1.96 SLE: 0.01 Item: 2-Pack Replacement f...
# 195: Guess: $38.50 Truth: $125.14 Error: $86.64 SLE: 1.35 Item: Global Solutions Glo...
# 196: Guess: $29.25 Truth: $29.99 Error: $0.74 SLE: 0.00 Item: Refrigmatic Electron...
# 197: Guess: $9.04 Truth: $7.98 Error: $1.06 SLE: 0.01 Item: 341241 Dryer Drum Be...
# 198: Guess: $29.97 Truth: $59.95 Error: $29.98 SLE: 0.46 Item: Spark Module (2+1) 1...
# 199: Guess: $11.00 Truth: $9.47 Error: $1.53 SLE: 0.02 Item: Washer Door Lid Swit...
# 200: Guess: $243.25 Truth: $129.99 Error: $113.26 SLE: 0.39 Item: Compact Refrigerator...
# 201: Guess: $19.47 Truth: $22.99 Error: $3.52 SLE: 0.03 Item: Washer Door Latch Sw...
# 202: Guess: $37.56 Truth: $37.42 Error: $0.14 SLE: 0.00 Item: Frigidaire Frigidare...
# 203: Guess: $20.30 Truth: $35.50 Error: $15.20 SLE: 0.29 Item: TRUE 810854 Black Ga...
# 204: Guess: $47.44 Truth: $39.99 Error: $7.45 SLE: 0.03 Item: Refrigerator Control...
# 205: Guess: $30.72 Truth: $29.99 Error: $0.73 SLE: 0.00 Item: ICEPURE PLUS NSF53 C...
# 206: Guess: $34.50 Truth: $28.99 Error: $5.51 SLE: 0.03 Item: Supplying Demand Clo...
# 207: Guess: $107.38 Truth: $380.12 Error: $272.75 SLE: 1.58 Item: Scotsman Pump Water
# ...
# 208: Guess: $12.19 Truth: $20.00 Error: $7.81 SLE: 0.22 Item: Whirlpool 482338 Adh...
# 209: Guess: $18.05 Truth: $16.99 Error: $1.06 SLE: 0.00 Item: 2-Pack Refrigerator ...
# 210: Guess: $23.69 Truth: $15.50 Error: $8.19 SLE: 0.16 Item: Whole Parts Applianc...
# 211: Guess: $9.26 Truth: $9.99 Error: $0.73 SLE: 0.00 Item: Dryer Lint Filter Re...
# 212: Guess: $17.20 Truth: $10.99 Error: $6.21 SLE: 0.17 Item: Supplying Demand Clo...
# 213: Guess: $9.05 Truth: $6.68 Error: $2.37 SLE: 0.07 Item: Refrigerator Door Li...
# 214: Guess: $11.86 Truth: $7.91 Error: $3.95 SLE: 0.13 Item: HQRP Filter Kit comp...
# 215: Guess: $13.97 Truth: $33.20 Error: $19.23 SLE: 0.68 Item: GENUINE Alliance Lau...
# 216: Guess: $7.02 Truth: $5.99 Error: $1.03 SLE: 0.02 Item: Replacement Light Bu...
# 217: Guess: $19.62 Truth: $53.99 Error: $34.37 SLE: 0.96 Item: Refrigerator Control...
# 218: Guess: $80.50 Truth: $149.95 Error: $69.45 SLE: 0.38 Item: NEW Control Board Mo...
# 219: Guess: $40.28 Truth: $28.59 Error: $11.69 SLE: 0.11 Item: GE Refrigerator Door...
# 220: Guess: $13.16 Truth: $17.25 Error: $4.09 SLE: 0.06 Item: Dishwasher Upper Dis...
# 221: Guess: $22.06 Truth: $39.99 Error: $17.93 SLE: 0.33 Item: AMI PARTS Universal ...
# 222: Guess: $36.12 Truth: $34.94 Error: $1.19 SLE: 0.00 Item: Evaporator Fan Motor...
# 223: Guess: $7.48 Truth: $7.99 Error: $0.51 SLE: 0.00 Item: 312959 Dryer Belt Re...
# 224: Guess: $306.00 Truth: $399.00 Error: $93.00 SLE: 0.07 Item: EKON 900CFM Range Ho...
# 225: Guess: $12.78 Truth: $16.48 Error: $3.70 SLE: 0.06 Item: EvertechPRO 57000 6f...
# 226: Guess: $89.25 Truth: $95.00 Error: $5.75 SLE: 0.00 Item: Compatible Ice Maker...
# 227: Guess: $36.28 Truth: $25.65 Error: $10.63 SLE: 0.11 Item: Edgewater Parts Evap...
# 228: Guess: $12.70 Truth: $9.91 Error: $2.79 SLE: 0.05 Item: HQRP Water Filter Co...
# 229: Guess: $90.62 Truth: $164.68 Error: $74.06 SLE: 0.35 Item: Apw Wyott Burner Cha...
# 230: Guess: $17.92 Truth: $20.99 Error: $3.07 SLE: 0.02 Item: Refrigerator Door Sh...
# 231: Guess: $45.19 Truth: $87.15 Error: $41.96 SLE: 0.42 Item: GE Appliances Genuin...
# 232: Guess: $16.44 Truth: $15.47 Error: $0.97 SLE: 0.00 Item: Cenipar Universal Di...
# 233: Guess: $37.91 Truth: $49.99 Error: $12.08 SLE: 0.07 Item: XNGJEMVWXO Dishwashe...
# 234: Guess: $114.94 Truth: $324.99 Error: $210.05 SLE: 1.07 Item: Captive Aire Make Up...
# 235: Guess: $32.25 Truth: $40.84 Error: $8.59 SLE: 0.05 Item: CH3301 Broil Element...
# 236: Guess: $11.91 Truth: $16.99 Error: $5.08 SLE: 0.11 Item: SILKYNICE Refrigerat...
# 237: Guess: $24.81 Truth: $42.98 Error: $18.17 SLE: 0.28 Item: Whole Parts Washer W...
# 238: Guess: $10.95 Truth: $22.99 Error: $12.04 SLE: 0.49 Item: Refrigerator Door Bi...
# 239: Guess: $17.64 Truth: $15.97 Error: $1.67 SLE: 0.01 Item: Nut Milk Bags for St...
# 240: Guess: $10.95 Truth: $12.98 Error: $2.03 SLE: 0.02 Item: spartshome iRomehony...
# 241: Guess: $51.66 Truth: $24.27 Error: $27.39 SLE: 0.54 Item: General Electric Ran...
# 242: Guess: $13.25 Truth: $15.99 Error: $2.74 SLE: 0.03 Item: Evaporator Fan Motor...
# 243: Guess: $43.50 Truth: $19.14 Error: $24.36 SLE: 0.63 Item: ORIGINAL Washer Door...
# 244: Guess: $13.01 Truth: $7.92 Error: $5.09 SLE: 0.20 Item: RANGE KLEEN R6-GE Ch...
# 245: Guess: $9.10 Truth: $10.99 Error: $1.89 SLE: 0.03 Item: Carbon Range Hood Fi...
# 246: Guess: $12.77 Truth: $9.99 Error: $2.78 SLE: 0.05 Item: Coffee milk can Capp...
# 247: Guess: $63.22 Truth: $165.30 Error: $102.08 SLE: 0.91 Item: Norcold Refrigerator...
# 248: Guess: $12.13 Truth: $6.99 Error: $5.14 SLE: 0.25 Item: Drawer Latch Replace...
# 249: Guess: $687.00 Truth: $505.10 Error: $181.90 SLE: 0.09 Item: KOBE Range Hoods Ins...
# 250: Guess: $20.84 Truth: $12.69 Error: $8.15 SLE: 0.22 Item: Appli Parts Washer L...
