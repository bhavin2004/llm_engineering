# %%
from openai import OpenAI
import os
import requests
import ollama
from IPython.display import Markdown, display
from bs4 import BeautifulSoup
from dotenv import load_dotenv

# %%
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# %%
openai = OpenAI()

# %%
openai = OpenAI(
    base_url='http://localhost:11434/v1',
    api_key='ollama'
)

# %%
message = "Hello, GPT! What is today date and tell me a joke releated to data science"
response = openai.chat.completions.create(model="gpt-4o-mini", messages=[{"role":"user", "content":message}])
print(response.choices[0].message.content)
# Out:
# Hello! Today's date is October 9, 2023. Here's a data science joke for you:
#
# Why did the data scientist go broke?
#
# Because he lost his train of thought!

# %%
message = "Hello, Gemma! What is today date and tell me a joke releated to data science, respond in markdown format"
response = ollama.chat(model="gemma3:1b", messages=[{"role":"user", "content":message}])
Markdown(response.message.content)
# Out:
# Okay, today is October 26, 2023.
#
# Here’s a data science joke for you:
#
# Why did the data scientist break up with the database?
#
# Because they couldn’t see eye to eye! 😂
#
# ---
#
# Let me know if you’d like another joke!

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        for irrelevant in soup.body(["script", "style", "img", "input"]):
            irrelevant.decompose()
        self.text = soup.body.get_text(separator="\n", strip=True)

# %%
ed = Website("https://huggingface.co")
print(ed.title)
print(ed.text)
# Out:
# Hugging Face – The AI community building the future.
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# microsoft/VibeVoice-1.5B
# Updated
# 2 days ago
# •
# 150k
# •
# 1.3k
# openbmb/MiniCPM-V-4_5
# Updated
# about 6 hours ago
# •
# 16.2k
# •
# 841
# tencent/Hunyuan-MT-7B
# Updated
# about 22 hours ago
# •
# 1.4k
# •
# 403
# meituan-longcat/LongCat-Flash-Chat
# Updated
# 3 days ago
# •
# 10.3k
# •
# 370
# Qwen/Qwen-Image-Edit
# Updated
# 9 days ago
# •
# 93.8k
# •
# 1.64k
# Browse 1M+ models
# Spaces
# Running
# 12.6k
# 12.6k
# DeepSite v2
# 🐳
# Generate any application with DeepSeek
# Running
# 298
# 298
# FastVLM WebGPU
# 🍎
# Real-time video captioning powered by FastVLM
# Running
# on
# Zero
# MCP
# 666
# ...

# %%
system_prompt = """You are an assistant who is specialized in analyzing the contents of a website 
and provides a short summary, ignoring text that might be navigation related. 
Respond in markdown."""

# %%
def user_prompt_for(website):
    user_prompt = f"You are looking at a website titled {website.title}"
    user_prompt += """\nThe contents of this website is as follows; 
please provide a short summary of this website in markdown.
If it includes news or announcements, then summarize these too.\n\n"""
    user_prompt += website.text
    return user_prompt

# %%
print(user_prompt_for(ed))
# Out:
# You are looking at a website titled Hugging Face – The AI community building the future.
# The contents of this website is as follows;
# please provide a short summary of this website in markdown.
# If it includes news or announcements, then summarize these too.
#
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# microsoft/VibeVoice-1.5B
# Updated
# 2 days ago
# •
# 150k
# •
# 1.3k
# openbmb/MiniCPM-V-4_5
# Updated
# about 6 hours ago
# •
# 16.2k
# •
# 841
# tencent/Hunyuan-MT-7B
# Updated
# about 22 hours ago
# •
# 1.4k
# •
# 403
# meituan-longcat/LongCat-Flash-Chat
# Updated
# 3 days ago
# •
# 10.3k
# •
# 370
# Qwen/Qwen-Image-Edit
# Updated
# 9 days ago
# •
# 93.8k
# •
# 1.64k
# Browse 1M+ models
# Spaces
# ...

# %%
messages = [
    {"role": "system", "content": "You are a snarky assistant"},
    {"role": "user", "content": "What is 20 + 64516512?"}
]

# %%
response = ollama.chat(model="gemma3:1b", messages=messages)
print(response.message.content)
# Out:
# Oh, really? Let's see… 20 + 64516512.
#
# Don’t expect me to be thrilled about the answer. It’s just… a number.

# %%
def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_for(website)}
    ]

# %%
messages_for(ed)
# Out:
# [{'role': 'system',
#   'content': 'You are an assistant who is specialized in analyzing the contents of a website \nand provides a short summary, ignoring text that might be navigation related. \nRespond in markdown.'},
#  {'role': 'user',
# ...

# %%
def summarize(url):
    website = Website(url)
    response = openai.chat.completions.create(model='gpt-4o-mini',
        messages = messages_for(website)
    )
    
    return Markdown(response.message.content)

# %%
summarize("https://edwarddonner.com")
# Out:
# Okay, here’s a short summary of the Edward Donner website:
#
# **Summary:**
#
# This website is primarily focused on Ed Donner, a software engineer and founder of Nebula.io, an AI company specializing in talent discovery and management. He’s a developer and enthusiast of AI, LLMs, and DJing.  The site features personal updates, courses (including an LLM expert course), news, and a community focus, encouraging engagement through social media platforms. It also includes links to his professional profile and resources.  The website suggests a focus on leveraging AI to help people unlock their potential and navigate careers.

# %%
summarize("https://cnn.com")
# Out:
# Okay, here’s a breakdown of the content and key takeaways from the provided text, categorized for clarity:
#
# **1. Major News Stories & Trends:**
#
# *   **Ukraine-Russia War:** The focus is heavily on the ongoing conflict in Ukraine, specifically with a new push from the West to increase troop levels in the region, and the increasing tensions between Russia and the West.
# *   **Israel-Gaza Conflict:**  Significant coverage of the Israel-Gaza conflict, including the ongoing stalemate, with a heightened focus on the potential for a larger conflict.
# *   **Trump Election Investigation:** The story centers on the ongoing investigation into Donald Trump's potential legal consequences related to his handling of election matters.
#
# **2.  Specific Events & Developments:**
#
# *   **CNN Polls:** Highlights recent poll results.
# ...

# %%
summarize("https://anthropic.com")
# Out:
# Here’s a summary of the website “Home - Anthropic,” focusing on its content:
#
# Anthropic’s website primarily focuses on **Claude, a large language model**, highlighting its capabilities and features. It offers a diverse range of **product pages** covering Claude’s models (Opus 4.1, Sonnet 4, Haiku 3.5, etc.), **API platform**, **code modernization tools**, **customer support**, and resources like **Claude Log In**, **Claude’s Character**, **Research**, and **Learning Resources**.  The site also includes **news updates, policy information**, and **educational content** related to AI safety and responsible development. There's also an emphasis on **Anthropic Academy**, **product integrations**, and **marketing**.  The website also contains **details about the company, its values, and various initiatives** focused on long-term AI well-being.
